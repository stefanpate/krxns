# %%
from pathlib import Path
import pandas as pd
from hydra import compose, initialize
from ergochemics.draw import draw_reaction, draw_molecule
from ergochemics.standardize import hash_compound
from IPython.display import SVG
from rdkit import Chem
import yaml
from collections import defaultdict

with initialize(version_base=None, config_path="../configs/filepaths"):
    cfg = compose("filepaths")

# %%
mi_rxns = pd.read_parquet(Path(cfg.raw_data) / "mapped_known_reactions_x_mechinformed_rules.parquet")
rc0_rxns = pd.read_parquet(Path(cfg.raw_data) / "mapped_known_reactions_x_rc_plus_0_rules.parquet")
all_rxns = pd.Series(list(set(mi_rxns["smarts"]).union(set(rc0_rxns["smarts"]))))
rxn_counts = defaultdict(int)
for smarts in all_rxns:
    lhs, rhs = [side.split(".") for side in smarts.split(">>")]
    for elt in set(lhs).union(set(rhs)):
        rxn_counts[hash_compound(elt)] += 1

# %%
cpds = pd.read_parquet(Path(cfg.raw_data) / "known_compounds.parquet")
cpds.head()
# Out:
#                                          id            smiles           name  \
# 0  df58248c414f342c81e056b40bee12d17a08bf61                 *              A
# 1  bc2f74c22f98f7b6ffbc2f67453dbfa99bce9a32                **             RX
# 2  e8ecd17bfc980925ff0b634bd13104c09dc4591f                *C      an alkane
# 3  b219689f21c828e7f057ef453af1187baa98fbf3              *C#N      a nitrile
# 4  94295b0379859ca57b86c85b0768526c711fe762  *C(*)(O)C(*)(*)O  an ethanediol
#
#        chebi_id  n_atoms
# 0   CHEBI:13193        1
# 1   CHEBI:17792        2
# 2   CHEBI:18310        2
# 3   CHEBI:18379        3
# 4  CHEBI:140594        8

# %%
cpds["rxn_count"] = cpds["id"].map(rxn_counts).fillna(0).astype(int)
cpds.sort_values(by="rxn_count", ascending=False, inplace=True)
cpds.head(20)
# Out:
#                                              id  \
# 8703   08a914cde05039694ef0194d9ee79ff9a79dde33
# 2007   795ce8b8f679817da1f0333c1a7ab70424422dd2
# 8679   07e48b419b37606b338ba3e838a8e5f56e1cef31
# 7961   da7b7aacec3c6f733a01920b971ac0deda5d3303
# 7907   27e471428018c3779a1b13dec34fcbc3d80f6c28
# 7959   599b0cd59ed43643b07bd6f1b3284abcbbb20811
# 7904   7a1e0d8109d1cad180288524e8d50ef4aee3a40d
# 9743   cd67f644cdcbc3175749023bdcb6d22159a5a57c
# 8650   d149421ac53cc62325e84c1688210e5ba639cbaf
# 9806   15b21be91dee61fcae45fcceab54182d7f4ab244
# 9740   1aa818910461f5961959eb05dd06b8f7a4fbbb9f
# 10021  032ad4a30e62a98cc92a81fc4e6d352006f30fdd
# 7419   e6490b8cb18f68ed72b12d82460b1384c017d3c6
# 8691   eef113d8ad6695378d0caebf7bae3a67b60c6323
# 9598   17d2ab53c78bed104290bde729ad657b5da216bb
# 10023  5bfb99425d410f7971f0aa0f48895479d9a43c0c
# 8617   4ea34a41c2091b9cd312119934909d0fb3217dc8
# 1930   b3d108052f15c3e212df2bd1df03c428da5b5957
# ...

# %%
default_sources = cpds.iloc[:20]["name"].values.tolist()

# %%
cpds["n_atoms"] = cpds["smiles"].apply(lambda x: Chem.MolFromSmiles(x).GetNumAtoms())
cpds.sort_values(by="n_atoms", ascending=True, inplace=True)
cpds.head(10)
# Out:
# [15:22:01] WARNING: not removing hydrogen atom with dummy atom neighbors
# [15:22:01] WARNING: not removing hydrogen atom with dummy atom neighbors
# [15:22:01] Unusual charge on atom 0 number of radical electrons set to zero
# [15:22:01] WARNING: not removing hydrogen atom with dummy atom neighbors
# [15:22:01] Unusual charge on atom 0 number of radical electrons set to zero
#                                              id  smiles      name  \
# 8703   08a914cde05039694ef0194d9ee79ff9a79dde33       O       H2O
# 7732   b51a60734da64be0e618bacbea2865a8a7dcd669       N    NH4(+)
# 10536  9feed07c52dc52431b11eb941fe5ca9a2b4300fb   [Cu+]     Cu(+)
# 10535  f5869f56736fc822ac2dbee43cff3ff7d8cfff45  [Cu+2]    Cu(2+)
# 10537  e0bafc74c3421ac1da0481a7128fc09d5ab7cfc1    [F-]  fluoride
# 10531  825a95e02d44036cef84801c1561cf7712ee921f   [Cl-]  chloride
# 10555  3d56d75ba7d0475a3195b58edf46f5f9ee109fdf  [Ni+2]    Ni(2+)
# 10534  9c54dc8891f6802eca1e53f74126e6b6487c86d0  [Cr+6]    Cr(6+)
# ...

# %%
default_sources.extend(["hydrogen sulfide", "methane"])

# %%
with open(Path(cfg.configs) / "sources" / "default.yaml", "w") as f:
    yaml.dump({"source_names": default_sources}, f)
