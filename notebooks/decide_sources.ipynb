# %%
from pathlib import Path
import pandas as pd
from hydra import compose, initialize
from ergochemics.draw import draw_reaction, draw_molecule
from IPython.display import SVG
from rdkit import Chem
import yaml

with initialize(version_base=None, config_path="../configs/filepaths"):
    cfg = compose("filepaths")

# %%
cpds = pd.read_csv(Path(cfg.interim_data) / "compounds.csv")
cpds.head()
# Out:
#    id            smiles                                          name  \
# 0   0              *C#N                                     a nitrile
# 1   1    *C(*)(N)C(=O)O                            2,2-dialkylglycine
# 2   2       *C(*)(O)C#N  a disubstituted aliphatic (S)-hydroxynitrile
# 3   3  *C(*)(O)C(*)(*)O                                 an ethanediol
# 4   4           *C(*)=O                                dialkyl ketone
#
#    rxn_count  n_atoms
# 0          6        3
# 1          2        7
# 2          2        6
# 3          2        8
# 4         14        4

# %%
cpds.sort_values(by="rxn_count", ascending=False, inplace=True)
cpds.head(20)
# Out:
#         id                                             smiles  \
# 5990  5990                                                  O
# 1910  1910  CC(C)(COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc...
# 5972  5972  Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O...
# 6612  6612                                                O=O
# 5468  5468  NC(=O)c1ccc[n+](C2OC(COP(=O)(O)OP(=O)(O)OCC3OC...
# 5426  5426  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...
# 5467  5467  NC(=O)c1ccc[n+](C2OC(COP(=O)(O)OP(=O)(O)OCC3OC...
# 6672  6672                                O=P(O)(O)OP(=O)(O)O
# 5423  5423  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...
# 6615  6615                                         O=P(O)(O)O
# 5949  5949    Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)O)C(O)C1O
# 6516  6516                                              O=C=O
# 5179  5179  C[S+](CCC(N)C(=O)O)CC1OC(n2cnc3c(N)ncnc32)C(O)C1O
# 5983  5983          Nc1ncnc2c1ncn2C1OC(CSCCC(N)C(=O)O)C(O)C1O
# 6780  6780  O=c1ccn(C2OC(COP(=O)(O)OP(=O)(O)O)C(O)C2O)c(=O...
# 5931  5931             Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O
# 5327  5327                                                  N
# 6264  6264                                O=C(O)CCC(=O)C(=O)O
# 6870  6870                                                 OO
# 1852  1852  CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP...
#
#                            name  rxn_count  n_atoms
# 5990                        H2O       4599        1
# 1910                        CoA       1870       48
# 5972                        ATP       1423       31
# 6612                         O2       1280        2
# 5468                    NADP(+)       1215       48
# 5426                      NADPH       1205       48
# 5467                     NAD(+)       1137       44
# 6672                diphosphate       1122        9
# 5423                       NADH       1064       44
# 6615                  phosphate        996        5
# 5949                        ADP        917       27
# 6516                        CO2        847        3
# 5179    S-adenosyl-L-methionine        742       27
# 5983  S-adenosyl-L-homocysteine        720       26
# 6780                        UDP        636       25
# 5931                        AMP        606       23
# 5327                     NH4(+)        442        1
# 6264             2-oxoglutarate        442       10
# 6870                       H2O2        404        2
# 1852                 acetyl-CoA        366       51

# %%
default_sources = cpds.iloc[:20]["name"].values.tolist()
default_sources.remove("2-oxoglutarate")

# %%
cpds["n_atoms"] = cpds["smiles"].apply(lambda x: Chem.MolFromSmiles(x).GetNumAtoms())
cpds.sort_values(by="n_atoms", ascending=True, inplace=True)
cpds.head(10)
# Out:
#         id smiles              name  rxn_count  n_atoms
# 5990  5990      O               H2O       4599        1
# 6917  6917      S  hydrogen sulfide         18        1
# 1262  1262      C           methane          4        1
# 5327  5327      N            NH4(+)        442        1
# 5102  5102     CS      methanethiol          8        2
# 4634  4634     CN       methylamine         18        2
# 585    585     *N   a primary amine         10        2
# 6612  6612    O=O                O2       1280        2
# 1510  1510    C=O      formaldehyde         74        2
# 1263  1263    C#C         acetylene          2        2

# %%
default_sources.extend(["hydrogen sulfide", "methane"])

# %%
with open(Path(cfg.configs) / "sources" / "default.yaml", "w") as f:
    yaml.dump({"source_names": default_sources}, f)
